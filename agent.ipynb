# %% [markdown]
# <a href="https://colab.research.google.com/github/AkritiGyawali/Cpp/blob/master/agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ddgs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 70.5 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import login

login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>AXYJ-8SQQ</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>gyawaliakriti</b> (token: <code>oauth-gyawaliakriti</code>).<br>This token will be refreshed automatically when it expires.</center>

# %%
# To fix this, you need to set the 'CH2' environment variable with your Hugging Face token.
# For example, in a separate cell, or at the beginning of this cell, you could run:
# import os
# os.environ["CH2"] = "YOUR_HUGGINGFACE_TOKEN_HERE"
from google.colab import userdata
from smolagents import CodeAgent, DuckDuckGoSearchTool,OpenAIModel , tool
import numpy as np
import time
import datetime


HF_TOKEN = userdata.get("Ch2")

model = OpenAIModel(
    model_id="openrouter/free",
    api_base="https://openrouter.ai/api/v1",
    api_key=HF_TOKEN
)
@tool
def suggest_menu(occasion:str) -> str:
  """
    Suggests a menu based on the occasion.
    Args:
        occasion (str): The type of occasion for the party .Allowed values are:
                        -"casual": Menu for casual party.
                        -"formal" : Menu for the formal party.
                        -"superhero" : Menu for the superhero party.
                        -"custom" : Custom menu.
  """
  if occasion == "casual":
    return "Pizza , snacks , and drinks"
  elif occasion == "formal":
    return "3-course dinner with wine and dessert"
  elif occasion == "superhero":
    return "Buffet with high energy and healthy food"
  else:

    return "Custom menu for the butler"

# Pass the HF_TOKEN to the InferenceClientModel
agent = CodeAgent(tools=[suggest_menu], model=model,additional_authorized_imports=['datetime'])

agent.run("""
          Alfred needs to prepare for the party. Here are the tasks:
          1. Prepare the drink - 30 min
          2. Decorate the mansion - 60 min
          3. Set up the menu - 45 min
          4. Prepare the music and playlist - 45 min

          If we start right now , at what time will the party be ready?
""")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Alfred needs to prepare for the party. Here are the tasks:                                                      │
# │           1. Prepare the drink - 30 min                                                                         │
# │           2. Decorate the mansion - 60 min                                                                      │
# │           3. Set up the menu - 45 min                                                                           │
# │           4. Prepare the music and playlist - 45 min                                                            │
# │                                                                                                                 │
# ...

# %%
# !pip install smolagents
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 4.6 MB/s eta 0:00:00
# ...
